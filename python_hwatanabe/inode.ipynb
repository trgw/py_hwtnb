# %%
! df -T
# Out:
# Filesystem     Type    1K-blocks     Used Available Use% Mounted on
# overlay        overlay  51343840 26291356  22414660  54% /
# tmpfs          tmpfs       65536        0     65536   0% /dev
# tmpfs          tmpfs     6667596        0   6667596   0% /sys/fs/cgroup
# tmpfs          tmpfs     6667596        8   6667588   1% /var/colab
# /dev/sda1      ext4     57581132 27560864  30003884  48% /etc/hosts
# shm            tmpfs     6291456        4   6291452   1% /dev/shm
# tmpfs          tmpfs     6667596        0   6667596   0% /proc/acpi
# tmpfs          tmpfs     6667596        0   6667596   0% /proc/scsi
# tmpfs          tmpfs     6667596        0   6667596   0% /sys/firmware

# %%
! touch test.txt
! stat test.txt
# Out:
#   File: test.txt
#   Size: 0         	Blocks: 0          IO Block: 4096   regular empty file
# Device: 2eh/46d	Inode: 1847940     Links: 1
# Access: (0644/-rw-r--r--)  Uid: (    0/    root)   Gid: (    0/    root)
# Access: 2019-11-05 06:40:53.372961297 +0000
# Modify: 2019-11-05 06:40:53.372961297 +0000
# Change: 2019-11-05 06:40:53.372961297 +0000
#  Birth: -

# %%
! ls -F -i1
# Out:
# 1966578 sample_data/
# 1847940 test.txt
