# %%
from random import choice, seed
from copy import copy

# %%
def keep(boxes):
  answer = choice(boxes)
  first_choice = choice(boxes)
  return answer == first_choice

# %%
seed(1)
boxes = [1,2,3]
for _ in range(10):
  print(keep(boxes))
# Out:
# False
# False
# False
# True
# False
# True
# False
# True
# False
# False

# %%
def change(boxes):
  answer = choice(boxes)
  first_choice = choice(boxes)
  rest_boxes = boxes.copy()
  rest_boxes.remove(answer)
  if first_choice == True:
    second_choice = random.choice(boxes - first_choice)
  else:
    second_choice = random.choice(rest_boxes - first_choice)
  return answer == second_choice

# %%
seed(1)
boxes = [1,2,3]
for _ in range(10):
  print(change(boxes))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-fa5d165775ed> in <module>()
#       2 boxes = [1,2,3]
#       3 for _ in range(10):
# ----> 4   print(change(boxes))
#
# <ipython-input-5-33127080a83f> in change(boxes)
#       7     second_choice = random.choice(boxes - first_choice)
#       8   else:
# ----> 9     second_choice = random.choice(rest_boxes - first_choice)
#      10   return answer == second_choice
#
# NameError: name 'random' is not defined
