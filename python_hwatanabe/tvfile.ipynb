# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
# !wget https://kaityo256.github.io/python_zero/file/colortv.csv
# Out:
# --2019-11-05 06:27:12--  https://kaityo256.github.io/python_zero/file/colortv.csv
# Resolving kaityo256.github.io (kaityo256.github.io)... 185.199.109.153, 185.199.111.153, 185.199.110.153, ...
# Connecting to kaityo256.github.io (kaityo256.github.io)|185.199.109.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162 [text/csv]
# Saving to: ‘colortv.csv’
#
# colortv.csv         100%[===================>]     162  --.-KB/s    in 0s
#
# 2019-11-05 06:27:12 (14.3 MB/s) - ‘colortv.csv’ saved [162/162]

# %%
# !head colortv.csv
# Out:
# 1966,0.3
# 1967,1.6
# 1968,5.4
# 1969,13.9
# 1970,26.3
# 1971,42.3
# 1972,61.1
# 1973,75.8
# 1974,85.9
# 1975,90.3

# %%
tv_year = []
tv_data = []
with open("colortv.csv") as f:
  for line in f:
    y, d = line.split(",")
    tv_year.append(int(y))
    tv_data.append(float(d))
    plt.scatter(tv_year, tv_data)

# %%
# !wget https://kaityo256.github.io/python_zero/file/lifespan.csv
# Out:
# --2019-11-05 06:32:08--  https://kaityo256.github.io/python_zero/file/lifespan.csv
# Resolving kaityo256.github.io (kaityo256.github.io)... 185.199.109.153, 185.199.111.153, 185.199.110.153, ...
# Connecting to kaityo256.github.io (kaityo256.github.io)|185.199.109.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 178 [text/csv]
# Saving to: ‘lifespan.csv’
#
# lifespan.csv        100%[===================>]     178  --.-KB/s    in 0s
#
# 2019-11-05 06:32:08 (32.8 MB/s) - ‘lifespan.csv’ saved [178/178]

# %%
# !head lifespan.csv
# Out:
# 1966,68.35
# 1967,68.91
# 1968,69.05
# 1969,69.18
# 1970,69.31
# 1971,70.17
# 1972,70.5
# 1973,70.7
# 1974,71.16
# 1975,71.73

# %%
life_year = []
life_data = []
with open("lifespan.csv") as f:
  for line in f:
    y, d = line.split(",")
    life_year.append(int(y))
    life_data.append(float(d))
plt.scatter(life_year, life_data)

# %%
plt.xlabel("TV")
plt.ylabel("Lifespan")
plt.scatter(tv_data, life_data)

# %%
np.corrcoef(tv_data, life_data)
# Out:
# array([[1.        , 0.94816361],
#        [0.94816361, 1.        ]])
