# %%
def newton(x):
  for _ in range(10):
    x = x - (x**3-1)/(3*x**2)
    print(x)
newton(2.0)
# Out:
# 1.4166666666666665
# 1.1105344098423684
# 1.0106367684045563
# 1.0001115573039492
# 1.0000000124431812
# 1.0000000000000002
# 1.0
# 1.0
# 1.0
# 1.0
